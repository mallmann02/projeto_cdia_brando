# %%
import mysql.connector
import pandas as pd

# %% [markdown]
# ### cons_reg table

# %%
cnx = mysql.connector.connect(
    host="www.medbase.com.br",
    user="mwcco814_dani_c01",
    password="turma_puc@240101",
    database="mwcco814_brando_pucrs_dc01"
)

# Criar um cursor
cursor = cnx.cursor()

# Executar a consulta para obter os dados da tabela cond_add
query = "SELECT * FROM cons_reg"
cursor.execute(query)

# Obter os resultados
data = cursor.fetchall()

# Obter os nomes das colunas
cursor.execute("SHOW COLUMNS FROM cons_reg")
columns = [column[0] for column in cursor.fetchall()]

# Criar o DataFrame
df_cons_reg = pd.DataFrame(data, columns=columns)

# Fechar o cursor e a conexão
cursor.close()
cnx.close()

# Exibir o DataFrame
df_cons_reg.head()

# %%
columns_cons_reg_fornecida = [
    "id_cons_reg",
    "npac",
    "dt_cons_reg",
    "tabagismo",
    "etilismo",
    "uso_cannabis",
    "outras_drogas",
    "uso_drogas_descr",
    "estado_civil_cons",
    "ativ_labor_cons",
    "efeito_adverso_med",
    "relata_surto",
    "progressao_clinica",
    "piora_radiologica",
    "melhora_clinica",
    "edss_visual",
    "edss_tronco",
    "edss_piramidal",
    "edss_cerebelar",
    "edss_sensorio",
    "edss_int_bexi",
    "edss_mental",
    "edss_deambulacao",
    "edss_fs_score",
    "edss_ambulat_score",
    "edss_total_calc",
    "edss_total_obs",
    "nht_mao_domin1",
    "nht_mao_domin1_irt",
    "nht_mao_n_domin1",
    "nht_mao_n_domin1_irt",
    "nht_mao_domin2",
    "nht_mao_domin2_irt",
    "nht_mao_n_domin2",
    "nht_mao_n_domin2_irt",
    "pasat_test",
    "pasat_test_irt",
    "sd_test",
    "sd_test_irt",
    "t25_fw_1",
    "t25_fw_1_irt",
    "t25_fw_2",
    "t25_fw_2_irt",
    "cvlt2",
    "cvlt2_irt",
    "bvmtr",
    "bvmtr_irt",
    "mfis",
    "mfis_irt",
    "fss",
    "fss_irt",
    "bai",
    "bai_irt",
    "bdi",
    "bdi_irt",
    "hads_a",
    "hads_a_irt",
    "hads_d",
    "hads_d_irt",
    "solicita_pulsoterapia",
    "cond_dmd",
    "cond_trat_sint",
    "cond_trat_out",
    "se_rm_encefalo",
    "se_rm_col_cerv",
    "se_rm_col_tor",
    "se_lab_rotina",
    "se_ind_jcv",
    "enc_neuropsic",
    "enc_fisio_mot",
    "enc_reab_cog",
    "enc_med1",
    "descr_outra_enc_med1",
    "enc_med2",
    "descr_outra_enc_med2",
    "enc_med3",
    "descr_outra_enc_med3",
    "hosp_completar_investigacao",
    "hosp_aplicar_dmd",
    "ori_parar_fumo",
    "ori_higi_sono",
    "ori_ativ_fisica",
    "coment_cons_reg"
]

columns_cons_reg_littlebrando = [
    "id_cons_reg",
    "npac",
    "dt_cons_reg",
    "tabagismo",
    "etilismo",
    "uso_cannabis",
    "outras_drogas",
    "uso_drogas_descr",
    "estado_civil_cons",
    "ativ_labor_cons",
    "efeito_adverso_med",
    "alteracao_sono",
    "alteracao_control_esfinct",
    "disfuncao_sexual",
    "relata_surto",
    "progressao_clinica",
    "piora_radiologica",
    "melhora_clinica",
    "st_cons_ativ_msrr",
    "st_cons_prog_mssp",
    "st_cons_prog_mspp",
    "edss_visual",
    "edss_tronco",
    "edss_piramidal",
    "edss_cerebelar",
    "edss_sensorio",
    "edss_int_bexi",
    "edss_mental",
    "edss_deambulacao",
    "edss_fs_score",
    "edss_ambulat_score",
    "edss_total_calc",
    "edss_total_obs",
    "nht_mao_domin1",
    "nht_mao_domin1_irt",
    "nht_mao_n_domin1",
    "nht_mao_n_domin1_irt",
    "nht_mao_domin2",
    "nht_mao_domin2_irt",
    "nht_mao_n_domin2",
    "nht_mao_n_domin2_irt",
    "pasat_test",
    "pasat_test_irt",
    "sd_test",
    "sd_test_irt",
    "t25_fw_1",
    "t25_fw_1_irt",
    "t25_fw_2",
    "t25_fw_2_irt",
    "cvlt2",
    "cvlt2_irt",
    "bvmtr",
    "bvmtr_irt",
    "mfis",
    "mfis_irt",
    "fss",
    "fss_irt",
    "bai",
    "bai_irt",
    "bdi",
    "bdi_irt",
    "hads_a",
    "hads_a_irt",
    "hads_d",
    "hads_d_irt",
    "solicita_pulsoterapia",
    "cond_dmd",
    "cond_trat_sint",
    "cond_trat_out",
    "se_rm_encefalo",
    "se_rm_col_cerv",
    "se_rm_col_tor",
    "se_lab_rotina",
    "se_ind_jcv",
    "se_outro_exame",
    "se_outro_exame_coment",
    "enc_neuropsic",
    "enc_fisio_mot",
    "enc_reab_cog",
    "enc_med1",
    "descr_outra_enc_med1",
    "enc_med2",
    "descr_outra_enc_med2",
    "enc_med3",
    "descr_outra_enc_med3",
    "hosp_completar_investigacao",
    "hosp_aplicar_dmd",
    "ori_parar_fumo",
    "ori_higi_sono",
    "ori_ativ_fisica",
    "discuss_plan_gestacional",
    "exn_global_ok",
    "exn_nvc_ok",
    "exn_nvc_moe_ok",
    "exn_nvc_onc_ok",
    "exn_spi_ok",
    "exn_spi_frc_ok",
    "exn_spi_rmt_ok",
    "exn_sce_ok",
    "exn_sse_ok",
    "exn_snellen_od",
    "exn_snellen_oe",
    "exn_nistagmo",
    "exn_disartria",
    "exn_moe_03_od",
    "exn_moe_03_oe",
    "exn_moe_04_od",
    "exn_moe_04_oe",
    "exn_moe_06_od",
    "exn_moe_06_oe",
    "exn_nvc_05",
    "exn_nvc_06",
    "exn_nvc_07",
    "exn_nvc_08",
    "exn_nvc_09",
    "exn_nvc_10",
    "exn_nvc_11",
    "exn_nvc_12",
    "exn_spi_frc_msd",
    "exn_spi_frc_mse",
    "exn_spi_frc_mid",
    "exn_spi_frc_mie",
    "exn_spi_rmt_bic_d",
    "exn_spi_rmt_bic_e",
    "exn_spi_rmt_trc_d",
    "exn_spi_rmt_trc_e",
    "exn_spi_rmt_pat_d",
    "exn_spi_rmt_pat_e",
    "exn_spi_rmt_aqu_d",
    "exn_spi_rmt_aqu_e",
    "exn_spi_rmt_out",
    "exn_spi_rmt_out_descr",
    "exn_spi_bab",
    "exn_spi_hof",
    "exn_spi_hpe",
    "exn_spi_hpe_descr",
    "exn_spi_cln",
    "exn_spi_cln_descr",
    "exn_sce_atx_tronco",
    "exn_sce_atx_apend",
    "exn_sce_atx_apend_descr",
    "exn_sce_atx_apend_intens",
    "exn_sce_atx_marcha",
    "exn_sce_romberg",
    "exn_sse_hps_tatil",
    "exn_sse_hps_tatil_descr",
    "exn_sse_hps_tatil_intens",
    "exn_sse_hps_dor",
    "exn_sse_hps_dor_descr",
    "exn_sse_hps_dor_intens",
    "exn_sse_hps_vibrat",
    "exn_sse_hps_vibrat_descr",
    "exn_sse_hps_vibrat_intens",
    "exn_sse_hps_reduc_ppc",
    "exn_sse_hps_reduc_ppc_descr",
    "exn_sse_hps_reduc_ppc_intens",
    "exn_comentarios",
    "coment_cons_reg"
]

# %%
# Converter as listas em conjuntos (sets)
set_littlebrando = set(columns_cons_reg_littlebrando)
set_cons_reg = set(columns_cons_reg_fornecida)

# Encontrar as palavras que existem em set_littlebrando mas não em set_cons_reg
difference = set_littlebrando - set_cons_reg
difference2 = set_cons_reg - set_littlebrando

# Converter de volta para lista (opcional)
difference_list = list(difference)
difference_list2 = list(difference2)

# Exibir o resultado
print("Palavras em columns_cons_reg_littlebrando que não existem em columns_cons_reg:")
print(difference_list)
print(len(difference_list))
print(len(difference_list2))

#Dropando as colunas para as quais não temos dicionário
cons_reg_filtered = df_cons_reg.drop(columns=difference_list)

# %%
# select the pacient with number 4708
cons_reg_filtered[(cons_reg_filtered['npac'] == 3547)]

# %%
cons_reg_filtered.groupby("npac").size().sort_values(ascending=False)

# %%
# cons_reg_filtered[cons_reg_filtered["coment_cons_reg"].notnull()].to_csv("pac_data/cons_reg_banco.csv", index=False)

# %% [markdown]
# ### surtos_reg table

# %%
cnx = mysql.connector.connect(
    host="www.medbase.com.br",
    user="mwcco814_dani_c01",
    password="turma_puc@240101",
    database="mwcco814_brando_pucrs_dc01"
)

# Criar um cursor
cursor = cnx.cursor()

# Executar a consulta para obter os dados da tabela cond_add
query = "SELECT * FROM surtos_reg"
cursor.execute(query)

# Obter os resultados
data = cursor.fetchall()

# Obter os nomes das colunas
cursor.execute("SHOW COLUMNS FROM surtos_reg")
columns = [column[0] for column in cursor.fetchall()]

# Criar o DataFrame
df_surtos_reg = pd.DataFrame(data, columns=columns)

# Fechar o cursor e a conexão
cursor.close()
cnx.close()

# Exibir o DataFrame
df_surtos_reg.head()

# %%
df_surtos_reg[df_surtos_reg["npac"] == 4708].iloc[0]["coment_surtos_reg"]

# %%
# df_surtos_reg[df_surtos_reg["coment_surtos_reg"].notnull()].to_csv("pac_data/t_surtos_reg.csv", index=False)
